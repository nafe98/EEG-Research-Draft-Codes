# %% [markdown]
# # About Dataset

# %% [markdown]
# The dataset contains EEG signals from 11 subjects with labels of alert and drowsy. It can be opened with Matlab. We extracted the data for our own research purpose from another public dataset:
#
# Cao, Z., et al., Multi-channel EEG recordings during a sustained-attention driving task. Scientific data, 2019. 6(1): p. 1-8.
#
# If you find the dataset useful, please give credits to their works.
#
# The details on how the data were extracted are described in our paper:
#
# "Jian Cui, Zirui Lan, Yisi Liu, Ruilin Li, Fan Li, Olga Sourina, Wolfgang Müller-Wittig, A Compact and Interpretable Convolutional Neural Network for Cross-Subject Driver Drowsiness Detection from Single-Channel EEG, Methods, 2021, ISSN 1046-2023, https://doi.org/10.1016/j.ymeth.2021.04.017."
#
# The codes of the paper above are accessible from:
#
# https://github.com/cuijiancorbin/A-Compact-and-Interpretable-Convolutional-Neural-Network-for-Single-Channel-EEG
#
# The data file contains 3 variables and they are EEGsample, substate and subindex.
#
# "EEGsample" contains 2022 EEG samples of size 20x384 from 11 subjects. Each sample is a 3s EEG data with 128Hz from 30 EEG channels.
# "subindex" is an array of 2022x1. It contains the subject indexes from 1-11 corresponding to each EEG sample.
# "substate" is an array of 2022x1. It contains the labels of the samples. 0 corresponds to the alert state and 1 correspond to the drowsy state.
#
# The unbalanced version of this dataset is accessible from:
# https://figshare.com/articles/dataset/EEG_driver_drowsiness_dataset_unbalanced_/16586957

# %% [markdown]
# An open EEG dataset released in 2019 by Cao et al. [38] was used in our study. The dataset contains 62 EEG data sets
# collected from 27 subjects (aged between 22 and 28) during 2005–2012. The participants were students or staff from the National
# Chiao Tung University.
# A sustained-attention driving task was implemented in a simulated VR driving simulator. The participants were asked to
# drive and keep the car in the center of a lane. In order to simulate small changes in road curvature or stones on the way that
# makes car drift, lane-departure events were randomly introduced which drifted the car to the left or the right from the central
# lane. The participants were asked to keep their attention during the whole experiment and respond immediately to the lanedeparture events by steering the car back to center of the lane. Each lane-departure event was defined as a “trial”, which includes
# a baseline period, deviation onset (when the car starts to drift), response onset (when the participant starts to turn the wheel) and
# response offset (when the car returns to the central lane). The unexciting and monotonous task could easily make participants
# feel drowsy.
# The EEG signals were sampled at a rate of 500 Hz during the whole experiment by a wired EEG cap with 30 EEG electrodes
# and 2 reference electrodes, which were placed according to a modified international 10–20 system. Both the raw and the
# processed datasets are available online.

# %% [markdown]
# # Importing Libraires

# %%
import pandas as pd
from scipy.io import loadmat

# %% [markdown]
# # Loading Dataset

# %%
EEG_dataset = loadmat(r"EEG driver drowsiness dataset.mat")

# %%
print(EEG_dataset)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Thu Dec 12 16:15:31 2019', '__version__': '1.0', '__globals__': [], 'EEGsample': array([[[ 4.08097622e+00,  5.36373657e+00,  2.16892286e+00, ...,
#          -2.43467111e+00, -1.08033326e+01, -4.06570287e+00],
#         [ 3.78602291e+00,  6.18806022e+00,  1.72710622e+00, ...,
#          -2.23788269e+00, -1.08040545e+01, -3.16985550e+00],
#         [ 8.34680437e+00,  8.69160090e+00, -1.09056499e-02, ...,
#           2.30521997e+00, -1.33921422e+01, -5.27739673e+00],
#         ...,
#         [ 1.52884814e+00,  7.93795880e-01, -1.45126572e+00, ...,
#          -1.22710349e+00, -5.26310889e+00, -1.22684549e+00],
#         [-1.19949821e+00, -1.54496214e+00, -4.31985930e+00, ...,
#          -5.32550694e+00, -5.48814272e+00, -1.57636907e+00],
#         [ 1.59400945e+00,  1.90051435e+00, -4.64426331e+00, ...,
#          -3.48251971e+00, -2.09547756e+00,  4.01980667e+00]],
#
# ...

# %%
print(EEG_dataset.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'EEGsample', 'subindex', 'substate'])

# %%
EEGsample = EEG_dataset['EEGsample']
subindex = EEG_dataset['subindex']
substate = EEG_dataset['substate']

# %% [markdown]
# # EEGsample

# %%
EEGsample.shape
# Out:
# (2022, 30, 384)

# %% [markdown]
# #### "EEGsample" contains 2022 EEG samples of size 20x384 from 11 subjects. Each sample is a 3s EEG data with 128Hz from 30 EEG channels.

# %% [markdown]
# The description you provided refers to a dataset or data structure called "EEGsample" that contains EEG (Electroencephalogram) data. Let's break down the information:
#
# 1. "EEGsample" is likely the name or identifier of the dataset.
#
# 2. "2022 EEG samples" means that there are 2022 individual sets of EEG data in this dataset. Each of these samples represents a distinct recording or measurement of brain electrical activity.
#
# 3. "20x384" refers to the dimensions of each EEG sample. It indicates that each sample is a matrix or array with a size of 20 rows and 384 columns. These dimensions likely correspond to some kind of spatial or temporal arrangement of EEG data points.
#
# 4. "3s EEG data" means that each EEG sample represents a 3-second window of EEG recordings. This is the time duration for which the electrical activity of the brain is captured in each sample.
#
# 5. "128Hz" indicates the sampling rate of the EEG data. It means that the EEG machine recorded data at a rate of 128 samples per second, which is a common sampling rate for EEG recordings.
#
# 6. "30 EEG channels" suggests that there are 30 distinct measurement channels used to capture EEG signals. These channels could be placed on the scalp to record electrical activity from different regions of the brain.
#
# In summary, "EEGsample" is a dataset containing 2022 EEG samples, each consisting of 20x384 data points captured over a 3-second period from 30 EEG channels, with a sampling rate of 128Hz.

# %% [markdown]
# # Subindex

# %%
subindex.shape
# Out:
# (2022, 1)

# %% [markdown]
# #### "subindex" is an array of 2022x1. It contains the subject indexes from 1-11 corresponding to each EEG sample.

# %% [markdown]
# # Substate

# %%
substate.shape
# Out:
# (2022, 1)

# %% [markdown]
# #### "substate" is an array of 2022x1. It contains the labels of the samples. 0 corresponds to the alert state and 1 correspond to the drowsy state.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Check the shape of the EEG data
print("EEGsample shape:", EEGsample.shape)

# Get the number of samples, channels, and time points
num_samples, num_channels, num_time_points = EEGsample.shape

# Calculate the duration of each sample in seconds
sampling_rate = 128  # Hz
sample_duration = num_time_points / sampling_rate

print("Number of Samples:", num_samples)
print("Number of Channels:", num_channels)
print("Number of Time Points:", num_time_points)
print("Sample Duration (seconds):", sample_duration)

# Plot a sample EEG data from a random subject and channel
random_subject_index = np.random.randint(0, num_samples)
random_channel_index = np.random.randint(0, num_channels)

plt.figure(figsize=(12, 4))
plt.plot(np.arange(num_time_points) / sampling_rate, EEGsample[random_subject_index, random_channel_index, :])
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title(f"EEG Sample - Subject {random_subject_index + 1}, Channel {random_channel_index + 1}")
plt.grid(True)
plt.show()
# Out:
# EEGsample shape: (2022, 30, 384)
# Number of Samples: 2022
# Number of Channels: 30
# Number of Time Points: 384
# Sample Duration (seconds): 3.0

# %%
# Describe the EEG data
print("EEG Data Description:")
print("Source: Electroencephalogram recordings")
print("Purpose: Research in neuroscience")
print("Context: [Provide relevant context]")

# Compute summary statistics
mean_amplitude = np.mean(EEGsample)
median_amplitude = np.median(EEGsample)
std_deviation = np.std(EEGsample)
quartiles = np.percentile(EEGsample, [25, 50, 75])

print("Summary Statistics:")
print("Mean Amplitude:", mean_amplitude)
print("Median Amplitude:", median_amplitude)
print("Standard Deviation:", std_deviation)
print("Quartiles (25th, 50th, 75th):", quartiles)
# Out:
# EEG Data Description:
# Source: Electroencephalogram recordings
# Purpose: Research in neuroscience
# Context: [Provide relevant context]
# Summary Statistics:
# Mean Amplitude: -0.032897111658380156
# Median Amplitude: -0.020543045214881206
# Standard Deviation: 20.014940463647438
# Quartiles (25th, 50th, 75th): [-5.11899504 -0.02054305  5.00780485]

# %%
# Visualize a sample EEG signal
plt.figure(figsize=(12, 4))
plt.plot(np.arange(num_time_points) / sampling_rate, EEGsample[random_subject_index, random_channel_index, :])
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title(f"EEG Sample - Subject {random_subject_index + 1}, Channel {random_channel_index + 1}")
plt.grid(True)
plt.show()

# %%
from scipy.fft import fft

# Compute the FFT of a sample EEG signal
eeg_signal = EEGsample[random_subject_index, random_channel_index, :]
freq_domain = np.fft.fftfreq(num_time_points, 1 / sampling_rate)
fft_values = np.abs(fft(eeg_signal))

# Plot the power spectral density
plt.figure(figsize=(10, 6))
plt.plot(freq_domain, fft_values)
plt.title("Power Spectral Density")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.grid(True)
plt.show()

# %%
# Calculate correlation matrix between EEG channels
correlation_matrix = np.corrcoef(EEGsample[random_subject_index])
plt.figure(figsize=(10, 8))
plt.imshow(correlation_matrix, cmap='viridis', aspect='auto')
plt.title("EEG Channel Correlation Matrix")
plt.colorbar()
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Flatten EEG data (if needed)
EEGsample_flat = EEGsample.reshape(num_samples, -1)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(EEGsample_flat, substate, test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Flatten EEG data (if needed)
# ----> 2 EEGsample_flat = EEGsample.reshape(num_samples, -1)
#       4 # Split data into training and testing sets
#       5 X_train, X_test, y_train, y_test = train_test_split(EEGsample_flat, substate, test_size=0.2, random_state=42)
#
# NameError: name 'EEGsample' is not defined

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Create a logistic regression model
model = LogisticRegression(random_state=42)

# Train the model
model.fit(X_train, y_train)

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Generate a classification report
print(classification_report(y_test, y_pred))

# Create a confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix/

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix



# Flatten EEG data (if needed)
num_samples, num_channels, num_time_points = EEGsample.shape
EEGsample_flat = EEGsample.reshape(num_samples, -1)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(EEGsample_flat, substate, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Build a deep learning model using tf.keras
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')  # Output layer with sigmoid activation for binary classification
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Make predictions on the test set
y_pred = (model.predict(X_test) > 0.5).astype("int32")  # Convert probabilities to binary labels

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Generate a classification report
print(classification_report(y_test, y_pred))

# Create a confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Epoch 1/10
# 41/41 [==============================] - 2s 7ms/step - loss: 1.2104 - accuracy: 0.5135 - val_loss: 0.9958 - val_accuracy: 0.5154
# Epoch 2/10
# 41/41 [==============================] - 0s 5ms/step - loss: 0.3602 - accuracy: 0.8453 - val_loss: 1.0481 - val_accuracy: 0.5031
# Epoch 3/10
# 41/41 [==============================] - 0s 5ms/step - loss: 0.1343 - accuracy: 0.9691 - val_loss: 1.1375 - val_accuracy: 0.5741
# Epoch 4/10
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0567 - accuracy: 0.9915 - val_loss: 1.1448 - val_accuracy: 0.5586
# Epoch 5/10
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0292 - accuracy: 0.9954 - val_loss: 1.2677 - val_accuracy: 0.5617
# Epoch 6/10
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0148 - accuracy: 0.9992 - val_loss: 1.2800 - val_accuracy: 0.5586
# Epoch 7/10
# ...
